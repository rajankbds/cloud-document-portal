# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# '/Users/rajankumar/document_portal/experiments'

# %%
logs_dir=os.path.join(os.getcwd(),"logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '12_04_2025_18_27_43.log'

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-12-04 18:31:14 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
class MyClass:
    def __init__(self, name):
        self.name = name
    
    def __str__(self):
        return f"MyClass object with name: {self.name}"
    
    def __repr__(self):
        return f"MyClass object with name: {self.name}"

# %%
obj=MyClass("sunny")

# %%
obj
# Out:
# MyClass object with name: sunny
